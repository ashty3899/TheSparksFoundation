# %% [markdown]
# # Data Preprocessing

# %%
#importing the required modules

import pandas as pd

# %%
#taking the data into dataframe

df = pd.read_csv('covid19_india_rawdata.csv')
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 15549  15550  2021-06-01  8:00 AM            Telangana
# 15550  15551  2021-06-01  8:00 AM              Tripura
# 15551  15552  2021-06-01  8:00 AM          Uttarakhand
# 15552  15553  2021-06-01  8:00 AM        Uttar Pradesh
# 15553  15554  2021-06-01  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
#dropping the unwanted column and renaming the other columns

df.drop(['ConfirmedIndianNational','ConfirmedForeignNational'] ,axis=1,inplace=True)
df.columns=['SrNo','Date','Time','State','Total_Cured','Total_Deaths','Total_Confirmed']
df
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 0          1  2020-01-30  6:00 PM         Kerala            0             0
# 1          2  2020-01-31  6:00 PM         Kerala            0             0
# 2          3  2020-02-01  6:00 PM         Kerala            0             0
# 3          4  2020-02-02  6:00 PM         Kerala            0             0
# 4          5  2020-02-03  6:00 PM         Kerala            0             0
# ...      ...         ...      ...            ...          ...           ...
# 15549  15550  2021-06-01  8:00 AM      Telangana       540986          3281
# 15550  15551  2021-06-01  8:00 AM        Tripura        44908           519
# 15551  15552  2021-06-01  8:00 AM    Uttarakhand       294671          6452
# 15552  15553  2021-06-01  8:00 AM  Uttar Pradesh      1633947         20497
# 15553  15554  2021-06-01  8:00 AM    West Bengal      1273788         15541
#
#        Total_Confirmed
# 0                    1
# ...

# %%
df.describe()
# Out:
#                SrNo   Total_Cured  Total_Deaths  Total_Confirmed
# count  15554.000000  1.555400e+04  15554.000000     1.555400e+04
# mean    7777.500000  1.898184e+05   2898.898804     2.110835e+05
# std     4490.197379  4.061648e+05   7637.201754     4.542665e+05
# min        1.000000  0.000000e+00      0.000000     0.000000e+00
# 25%     3889.250000  1.950250e+03     14.000000     3.177000e+03
# 50%     7777.500000  2.141550e+04    374.000000     2.874900e+04
# 75%    11665.750000  2.151482e+05   2527.000000     2.387830e+05
# max    15554.000000  5.395370e+06  95344.000000     5.746892e+06

# %%
#finding the count of null entries

df.isnull().sum()
# Out:
# SrNo               0
# Date               0
# Time               0
# State              0
# Total_Cured        0
# Total_Deaths       0
# Total_Confirmed    0
# dtype: int64

# %%
df.nunique()
# Out:
# SrNo               15554
# Date                 489
# Time                   7
# State                 40
# Total_Cured        11966
# Total_Deaths        5287
# Total_Confirmed    12522
# dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Lakshadweep', 'Telangana'], dtype=object)

# %%
df.loc[df['State']=='Unassigned']
# Out:
#      SrNo        Date     Time       State  Total_Cured  Total_Deaths  \
# 500   501  2020-03-30  9:30 PM  Unassigned            0             0
# 528   529  2020-03-31  8:30 PM  Unassigned            0             0
# 617   618  2020-04-03  6:00 PM  Unassigned            0             0
#
#      Total_Confirmed
# 500               46
# 528               38
# 617               77

# %%
df.loc[df['State']=='Cases being reassigned to states']
# Out:
#       SrNo        Date     Time                             State  \
# 2133  2134  2020-05-20  8:00 AM  Cases being reassigned to states
# 2167  2168  2020-05-21  8:00 AM  Cases being reassigned to states
# 2201  2202  2020-05-22  8:00 AM  Cases being reassigned to states
# 2235  2236  2020-05-23  8:00 AM  Cases being reassigned to states
# 2270  2271  2020-05-24  8:00 AM  Cases being reassigned to states
# 2305  2306  2020-05-25  8:00 AM  Cases being reassigned to states
# 2341  2342  2020-05-26  8:00 AM  Cases being reassigned to states
# 2377  2378  2020-05-27  8:00 AM  Cases being reassigned to states
# 2413  2414  2020-05-28  8:00 AM  Cases being reassigned to states
# 2449  2450  2020-05-29  8:00 AM  Cases being reassigned to states
# 2485  2486  2020-05-30  8:00 AM  Cases being reassigned to states
# 2521  2522  2020-05-31  8:00 AM  Cases being reassigned to states
# 2557  2558  2020-06-01  8:00 AM  Cases being reassigned to states
# ...

# %%
df.loc[df['State']=='Telengana']
# Out:
#         SrNo        Date     Time      State  Total_Cured  Total_Deaths  \
# 32        33  2020-03-02  6:00 PM  Telengana            0             0
# 35        36  2020-03-03  6:00 PM  Telengana            0             0
# 43        44  2020-03-04  6:00 PM  Telengana            0             0
# 49        50  2020-03-05  6:00 PM  Telengana            0             0
# 56        57  2020-03-06  6:00 PM  Telengana            0             0
# ...      ...         ...      ...        ...          ...           ...
# 14289  14290  2021-04-27  8:00 AM  Telengana       340590          2094
# 14325  14326  2021-04-28  8:00 AM  Telengana       345683          2150
# 14361  14362  2021-04-29  8:00 AM  Telengana       349692          2208
# 14397  14398  2021-04-30  8:00 AM  Telengana       355618          2261
# 14433  14434  2021-05-01  8:00 AM  Telengana       362160          2312
#
#        Total_Confirmed
# 32                   1
# 35                   1
# 43                   1
# ...

# %%
df.loc[df['State']=='Telangana']
# Out:
#         SrNo        Date     Time      State  Total_Cured  Total_Deaths  \
# 14469  14470  2021-05-02  8:00 AM  Telangana       367727          2368
# 14505  14506  2021-05-03  8:00 AM  Telangana       373933          2417
# 14541  14542  2021-05-04  8:00 AM  Telangana       381365          2476
# 14577  14578  2021-05-05  8:00 AM  Telangana       389491          2527
# 14613  14614  2021-05-06  8:00 AM  Telangana       396042          2579
# 14649  14650  2021-05-07  8:00 AM  Telangana       405164          2625
# 14685  14686  2021-05-08  8:00 AM  Telangana       413225          2666
# 14721  14722  2021-05-09  8:00 AM  Telangana       421219          2704
# 14757  14758  2021-05-10  8:00 AM  Telangana       428865          2739
# 14793  14794  2021-05-11  8:00 AM  Telangana       436619          2771
# 14829  14830  2021-05-12  8:00 AM  Telangana       444049          2803
# 14865  14866  2021-05-13  8:00 AM  Telangana       449744          2834
# ...

# %%
df.loc[df['State']=='Daman & Diu']
# Out:
#       SrNo        Date     Time        State  Total_Cured  Total_Deaths  \
# 2890  2891  2020-06-11  8:00 AM  Daman & Diu            0             0
#
#       Total_Confirmed
# 2890                2

# %%
df.loc[df['State']=='Dadra and Nagar Haveli and Daman and Diu']
# Out:
#         SrNo        Date     Time                                     State  \
# 1645    1646  2020-05-06  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 1678    1679  2020-05-07  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 1711    1712  2020-05-08  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 1744    1745  2020-05-09  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 1777    1778  2020-05-10  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# ...      ...         ...      ...                                       ...
# 15381  15382  2021-05-28  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 15417  15418  2021-05-29  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 15453  15454  2021-05-30  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 15489  15490  2021-05-31  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 15525  15526  2021-06-01  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
#
#        Total_Cured  Total_Deaths  Total_Confirmed
# ...

# %%
df["State"].replace({"Telengana": "Telangana"}, inplace=True)
df
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 0          1  2020-01-30  6:00 PM         Kerala            0             0
# 1          2  2020-01-31  6:00 PM         Kerala            0             0
# 2          3  2020-02-01  6:00 PM         Kerala            0             0
# 3          4  2020-02-02  6:00 PM         Kerala            0             0
# 4          5  2020-02-03  6:00 PM         Kerala            0             0
# ...      ...         ...      ...            ...          ...           ...
# 15549  15550  2021-06-01  8:00 AM      Telangana       540986          3281
# 15550  15551  2021-06-01  8:00 AM        Tripura        44908           519
# 15551  15552  2021-06-01  8:00 AM    Uttarakhand       294671          6452
# 15552  15553  2021-06-01  8:00 AM  Uttar Pradesh      1633947         20497
# 15553  15554  2021-06-01  8:00 AM    West Bengal      1273788         15541
#
#        Total_Confirmed
# 0                    1
# ...

# %%
df['State'].unique()
# Out:
# array(['Kerala', 'Telangana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Lakshadweep'], dtype=object)

# %%
len(df['State'].unique())
# Out:
# 39

# %%
df=df.loc[
    (df['State'] != "Cases being reassigned to states") & 
    (df['State'] != "Unassigned") & 
    (df['State'] != "Daman & Diu")]

# %%
df
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 0          1  2020-01-30  6:00 PM         Kerala            0             0
# 1          2  2020-01-31  6:00 PM         Kerala            0             0
# 2          3  2020-02-01  6:00 PM         Kerala            0             0
# 3          4  2020-02-02  6:00 PM         Kerala            0             0
# 4          5  2020-02-03  6:00 PM         Kerala            0             0
# ...      ...         ...      ...            ...          ...           ...
# 15549  15550  2021-06-01  8:00 AM      Telangana       540986          3281
# 15550  15551  2021-06-01  8:00 AM        Tripura        44908           519
# 15551  15552  2021-06-01  8:00 AM    Uttarakhand       294671          6452
# 15552  15553  2021-06-01  8:00 AM  Uttar Pradesh      1633947         20497
# 15553  15554  2021-06-01  8:00 AM    West Bengal      1273788         15541
#
#        Total_Confirmed
# 0                    1
# ...

# %%
len(df['State'].unique())
# Out:
# 36

# %%
df['State'].unique()
# Out:
# array(['Kerala', 'Telangana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Assam', 'Jharkhand', 'Arunachal Pradesh', 'Tripura',
#        'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Sikkim',
#        'Lakshadweep'], dtype=object)

# %%
newdf=df.copy()

# %%
newdf
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 0          1  2020-01-30  6:00 PM         Kerala            0             0
# 1          2  2020-01-31  6:00 PM         Kerala            0             0
# 2          3  2020-02-01  6:00 PM         Kerala            0             0
# 3          4  2020-02-02  6:00 PM         Kerala            0             0
# 4          5  2020-02-03  6:00 PM         Kerala            0             0
# ...      ...         ...      ...            ...          ...           ...
# 15549  15550  2021-06-01  8:00 AM      Telangana       540986          3281
# 15550  15551  2021-06-01  8:00 AM        Tripura        44908           519
# 15551  15552  2021-06-01  8:00 AM    Uttarakhand       294671          6452
# 15552  15553  2021-06-01  8:00 AM  Uttar Pradesh      1633947         20497
# 15553  15554  2021-06-01  8:00 AM    West Bengal      1273788         15541
#
#        Total_Confirmed
# 0                    1
# ...

# %%
#creating 3 new columns

newdf.loc[:, ('New_Cured','New_Deaths','New_Confirmed')]=[0,0,0]
newdf
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 0          1  2020-01-30  6:00 PM         Kerala            0             0
# 1          2  2020-01-31  6:00 PM         Kerala            0             0
# 2          3  2020-02-01  6:00 PM         Kerala            0             0
# 3          4  2020-02-02  6:00 PM         Kerala            0             0
# 4          5  2020-02-03  6:00 PM         Kerala            0             0
# ...      ...         ...      ...            ...          ...           ...
# 15549  15550  2021-06-01  8:00 AM      Telangana       540986          3281
# 15550  15551  2021-06-01  8:00 AM        Tripura        44908           519
# 15551  15552  2021-06-01  8:00 AM    Uttarakhand       294671          6452
# 15552  15553  2021-06-01  8:00 AM  Uttar Pradesh      1633947         20497
# 15553  15554  2021-06-01  8:00 AM    West Bengal      1273788         15541
#
# ...

# %%
newdf=newdf.sort_values(by=['State','Date'])
newdf
# Out:
#         SrNo        Date      Time                        State  Total_Cured  \
# 365      366  2020-03-26   6:00 PM  Andaman and Nicobar Islands            0
# 392      393  2020-03-27  10:00 AM  Andaman and Nicobar Islands            0
# 420      421  2020-03-28   6:00 PM  Andaman and Nicobar Islands            0
# 447      448  2020-03-29   7:30 PM  Andaman and Nicobar Islands            0
# 474      475  2020-03-30   9:30 PM  Andaman and Nicobar Islands            0
# ...      ...         ...       ...                          ...          ...
# 15409  15410  2021-05-28   8:00 AM                  West Bengal      1199120
# 15445  15446  2021-05-29   8:00 AM                  West Bengal      1218516
# 15481  15482  2021-05-30   8:00 AM                  West Bengal      1237290
# 15517  15518  2021-05-31   8:00 AM                  West Bengal      1255932
# 15553  15554  2021-06-01   8:00 AM                  West Bengal      1273788
#
# ...

# %%
NEWCONFLIST=[]
NEWCURELIST=[]
NEWDEATHLIST=[]
p=-1
for c in newdf.iterrows():
    if p==-1:
        NEWCURELIST.append(c[1][4])
        NEWDEATHLIST.append(c[1][5])
        NEWCONFLIST.append(c[1][6])
        
    elif p[1][3]==c[1][3]:
        NEWCURELIST.append(c[1][4]-p[1][4])
        NEWDEATHLIST.append(c[1][5]-p[1][5])
        NEWCONFLIST.append(c[1][6]-p[1][6])
    else:
        NEWCURELIST.append(c[1][4])
        NEWDEATHLIST.append(c[1][5])
        NEWCONFLIST.append(c[1][6])
    p=c

# %%
newdf['New_Cured']=NEWCURELIST
newdf['New_Deaths']=NEWDEATHLIST
newdf['New_Confirmed']=NEWCONFLIST
newdf
# Out:
#         SrNo        Date      Time                        State  Total_Cured  \
# 365      366  2020-03-26   6:00 PM  Andaman and Nicobar Islands            0
# 392      393  2020-03-27  10:00 AM  Andaman and Nicobar Islands            0
# 420      421  2020-03-28   6:00 PM  Andaman and Nicobar Islands            0
# 447      448  2020-03-29   7:30 PM  Andaman and Nicobar Islands            0
# 474      475  2020-03-30   9:30 PM  Andaman and Nicobar Islands            0
# ...      ...         ...       ...                          ...          ...
# 15409  15410  2021-05-28   8:00 AM                  West Bengal      1199120
# 15445  15446  2021-05-29   8:00 AM                  West Bengal      1218516
# 15481  15482  2021-05-30   8:00 AM                  West Bengal      1237290
# 15517  15518  2021-05-31   8:00 AM                  West Bengal      1255932
# 15553  15554  2021-06-01   8:00 AM                  West Bengal      1273788
#
# ...

# %%
newdf.sort_values(by=['New_Confirmed'])
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 12093  12094  2021-02-25  8:00 AM      Telangana       294782          1630
# 12509  12510  2021-03-09  8:00 AM      Karnataka       936250         12367
# 12286  12287  2021-03-03  8:00 AM          Delhi       627227         10911
# 9756    9757  2020-12-22  8:00 AM  Uttar Pradesh       550587          8212
# 11837  11838  2021-02-18  8:00 AM         Punjab       168833          5722
# ...      ...         ...      ...            ...          ...           ...
# 14134  14135  2021-04-23  8:00 AM    Maharashtra      3330747         62479
# 13954  13955  2021-04-18  8:00 AM    Maharashtra      3061174         59970
# 14206  14207  2021-04-25  8:00 AM    Maharashtra      3468610         63928
# 14098  14099  2021-04-22  8:00 AM    Maharashtra      3268449         61911
# 13990  13991  2021-04-19  8:00 AM    Maharashtra      3106828         60473
#
# ...

# %%
newdf.sort_values(by=['New_Cured'])
# Out:
#         SrNo        Date     Time                        State  Total_Cured  \
# 616      617  2020-04-03  6:00 PM                  West Bengal            3
# 160      161  2020-03-15  6:00 PM                Uttar Pradesh            4
# 365      366  2020-03-26  6:00 PM  Andaman and Nicobar Islands            0
# 1484    1485  2020-05-01  5:00 PM                 Chhattisgarh           36
# 1516    1517  2020-05-02  5:00 PM                 Chhattisgarh           36
# ...      ...         ...      ...                          ...          ...
# 14278  14279  2021-04-27  8:00 AM                  Maharashtra      3601796
# 14818  14819  2021-05-12  8:00 AM                  Maharashtra      4541391
# 14170  14171  2021-04-24  8:00 AM                  Maharashtra      3404792
# 14710  14711  2021-05-09  8:00 AM                  Maharashtra      4347592
# 15030  15031  2021-05-18  8:00 AM                       Kerala      1800179
#
# ...

# %%
newdf.sort_values(by=['New_Deaths'])
# Out:
#         SrNo        Date     Time                        State  Total_Cured  \
# 2158    2159  2020-05-21  8:00 AM                   Puducherry            9
# 365      366  2020-03-26  6:00 PM  Andaman and Nicobar Islands            0
# 13767  13768  2021-04-13  8:00 AM            Jammu and Kashmir       129439
# 4060    4061  2020-07-13  8:00 AM                   Puducherry          739
# 4096    4097  2020-07-14  8:00 AM                   Puducherry          785
# ...      ...         ...      ...                          ...          ...
# 15322  15323  2021-05-26  8:00 AM                  Maharashtra      5218768
# 15178  15179  2021-05-22  8:00 AM                  Maharashtra      5070801
# 15070  15071  2021-05-19  8:00 AM                  Maharashtra      4927480
# 15250  15251  2021-05-24  8:00 AM                  Maharashtra      5140272
# 3118    3119  2020-06-17  8:00 AM                  Maharashtra        57851
#
# ...

# %%
newdf.loc[newdf.New_Confirmed < 0, 'New_Confirmed'] = 0
newdf.loc[newdf.New_Cured < 0, 'New_Cured'] = 0
newdf.loc[newdf.New_Deaths < 0, 'New_Deaths'] = 0

# %%
newdf.sort_values(by=['New_Confirmed'])
# Out:
#         SrNo        Date     Time                                     State  \
# 11601  11602  2021-02-12  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 9513    9514  2020-12-16  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 9693    9694  2020-12-21  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 9729    9730  2020-12-22  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 10053  10054  2020-12-31  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# ...      ...         ...      ...                                       ...
# 14134  14135  2021-04-23  8:00 AM                               Maharashtra
# 13954  13955  2021-04-18  8:00 AM                               Maharashtra
# 14206  14207  2021-04-25  8:00 AM                               Maharashtra
# 14098  14099  2021-04-22  8:00 AM                               Maharashtra
# 13990  13991  2021-04-19  8:00 AM                               Maharashtra
#
# ...

# %%
newdf.sort_values(by=['New_Cured'])
# Out:
#         SrNo        Date     Time                        State  Total_Cured  \
# 365      366  2020-03-26  6:00 PM  Andaman and Nicobar Islands            0
# 1388    1389  2020-04-28  5:00 PM                 Chhattisgarh           32
# 1484    1485  2020-05-01  5:00 PM                 Chhattisgarh           36
# 1516    1517  2020-05-02  5:00 PM                 Chhattisgarh           36
# 1548    1549  2020-05-03  5:00 PM                 Chhattisgarh           36
# ...      ...         ...      ...                          ...          ...
# 14278  14279  2021-04-27  8:00 AM                  Maharashtra      3601796
# 14818  14819  2021-05-12  8:00 AM                  Maharashtra      4541391
# 14170  14171  2021-04-24  8:00 AM                  Maharashtra      3404792
# 14710  14711  2021-05-09  8:00 AM                  Maharashtra      4347592
# 15030  15031  2021-05-18  8:00 AM                       Kerala      1800179
#
# ...

# %%
newdf.sort_values(by=['New_Deaths'])
# Out:
#         SrNo        Date     Time                        State  Total_Cured  \
# 365      366  2020-03-26  6:00 PM  Andaman and Nicobar Islands            0
# 13767  13768  2021-04-13  8:00 AM            Jammu and Kashmir       129439
# 4060    4061  2020-07-13  8:00 AM                   Puducherry          739
# 4096    4097  2020-07-14  8:00 AM                   Puducherry          785
# 13263  13264  2021-03-30  8:00 AM            Jammu and Kashmir       126129
# ...      ...         ...      ...                          ...          ...
# 15322  15323  2021-05-26  8:00 AM                  Maharashtra      5218768
# 15178  15179  2021-05-22  8:00 AM                  Maharashtra      5070801
# 15070  15071  2021-05-19  8:00 AM                  Maharashtra      4927480
# 15250  15251  2021-05-24  8:00 AM                  Maharashtra      5140272
# 3118    3119  2020-06-17  8:00 AM                  Maharashtra        57851
#
# ...

# %%
newdf
# Out:
#         SrNo        Date      Time                        State  Total_Cured  \
# 365      366  2020-03-26   6:00 PM  Andaman and Nicobar Islands            0
# 392      393  2020-03-27  10:00 AM  Andaman and Nicobar Islands            0
# 420      421  2020-03-28   6:00 PM  Andaman and Nicobar Islands            0
# 447      448  2020-03-29   7:30 PM  Andaman and Nicobar Islands            0
# 474      475  2020-03-30   9:30 PM  Andaman and Nicobar Islands            0
# ...      ...         ...       ...                          ...          ...
# 15409  15410  2021-05-28   8:00 AM                  West Bengal      1199120
# 15445  15446  2021-05-29   8:00 AM                  West Bengal      1218516
# 15481  15482  2021-05-30   8:00 AM                  West Bengal      1237290
# 15517  15518  2021-05-31   8:00 AM                  West Bengal      1255932
# 15553  15554  2021-06-01   8:00 AM                  West Bengal      1273788
#
# ...

# %%
newdf=newdf.sort_values(by=['Date','State'])

# %%
newdf
# Out:
#         SrNo        Date     Time          State  Total_Cured  Total_Deaths  \
# 0          1  2020-01-30  6:00 PM         Kerala            0             0
# 1          2  2020-01-31  6:00 PM         Kerala            0             0
# 2          3  2020-02-01  6:00 PM         Kerala            0             0
# 3          4  2020-02-02  6:00 PM         Kerala            0             0
# 4          5  2020-02-03  6:00 PM         Kerala            0             0
# ...      ...         ...      ...            ...          ...           ...
# 15549  15550  2021-06-01  8:00 AM      Telangana       540986          3281
# 15550  15551  2021-06-01  8:00 AM        Tripura        44908           519
# 15552  15553  2021-06-01  8:00 AM  Uttar Pradesh      1633947         20497
# 15551  15552  2021-06-01  8:00 AM    Uttarakhand       294671          6452
# 15553  15554  2021-06-01  8:00 AM    West Bengal      1273788         15541
#
# ...

# %%
#Saving the processed data in a new csv file for visualization

newdf.drop(['SrNo','Time'] ,axis=1).to_csv('final.csv',index=None)
